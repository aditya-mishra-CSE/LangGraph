# %%
from langchain_google_genai import ChatGoogleGenerativeAI
from dotenv import load_dotenv
# Out:
# None of PyTorch, TensorFlow >= 2.0, or Flax have been found. Models won't be available and only tokenizers, configuration and file/data utilities can be used.

# %%
load_dotenv()
# Out:
# True

# %%
llm = ChatGoogleGenerativeAI(model='gemini-2.5-flash')

# %%
llm.invoke('My name is Aditya').content
# Out:
# 'Hello Aditya!'

# %%
llm.invoke('What is my name?').content
# Out:
# "As an AI, I don't have access to your personal information, including your name. I don't know who you are unless you choose to tell me."

# %%
messages = ['My name is Aditya']

# %%
output = llm.invoke(messages).content
output
# Out:
# 'Hello, Aditya! Nice to meet you.\n\nHow can I assist you today?'

# %%
messages.append(output)
messages
# Out:
# ['My nme is Aditya',
#  'Hello, Aditya! Nice to meet you.\n\nHow can I assist you today?']

# %%
messages.append('What is my name?')
messages
# Out:
# ['My nme is Aditya',
#  'Hello, Aditya! Nice to meet you.\n\nHow can I assist you today?',
#  'What is my name?']

# %%
output = llm.invoke(messages).content
output
# Out:
# 'Your name is Aditya.'
